# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
df = pd.read_csv('dataset_olympics.csv')

# %%
df
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 69999  35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# ...

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 69999  35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# ...

# %%
olympics_data = df.drop(['Height','Weight'],axis = 1)

# %%
olympics_data
# Out:
#           ID                            Name Sex   Age            Team  NOC  \
# 0          1                       A Dijiang   M  24.0           China  CHN
# 1          2                        A Lamusi   M  23.0           China  CHN
# 2          3             Gunnar Nielsen Aaby   M  24.0         Denmark  DEN
# 3          4            Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 4          5        Christine Jacoba Aaftink   F  21.0     Netherlands  NED
# ...      ...                             ...  ..   ...             ...  ...
# 69995  35656              Stuart Fitzsimmons   M  19.0   Great Britain  GBR
# 69996  35656              Stuart Fitzsimmons   M  19.0   Great Britain  GBR
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0       Australia  AUS
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0       Australia  AUS
# 69999  35658                    Marek Fiurek   M  23.0  Czech Republic  CZE
#
# ...

# %%
olympics_data.isnull().sum()
# Out:
# ID            0
# Name          0
# Sex           0
# Age        2671
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     59931
# dtype: int64

# %%
olympics_data['Medal'] = olympics_data['Medal'].fillna('Medal-less')

# %%
olympics_data
# Out:
#           ID                            Name Sex   Age            Team  NOC  \
# 0          1                       A Dijiang   M  24.0           China  CHN
# 1          2                        A Lamusi   M  23.0           China  CHN
# 2          3             Gunnar Nielsen Aaby   M  24.0         Denmark  DEN
# 3          4            Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 4          5        Christine Jacoba Aaftink   F  21.0     Netherlands  NED
# ...      ...                             ...  ..   ...             ...  ...
# 69995  35656              Stuart Fitzsimmons   M  19.0   Great Britain  GBR
# 69996  35656              Stuart Fitzsimmons   M  19.0   Great Britain  GBR
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0       Australia  AUS
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0       Australia  AUS
# 69999  35658                    Marek Fiurek   M  23.0  Czech Republic  CZE
#
# ...

# %%
olympics_data['Age'] = olympics_data['Age'].fillna(olympics_data['Age'].median())

# %%
olympics_data.isnull().sum()
# Out:
# ID        0
# Name      0
# Sex       0
# Age       0
# Team      0
# NOC       0
# Games     0
# Year      0
# Season    0
# City      0
# Sport     0
# Event     0
# Medal     0
# dtype: int64

# %%
olympics_data
# Out:
#           ID                            Name Sex   Age            Team  NOC  \
# 0          1                       A Dijiang   M  24.0           China  CHN
# 1          2                        A Lamusi   M  23.0           China  CHN
# 2          3             Gunnar Nielsen Aaby   M  24.0         Denmark  DEN
# 3          4            Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 4          5        Christine Jacoba Aaftink   F  21.0     Netherlands  NED
# ...      ...                             ...  ..   ...             ...  ...
# 69995  35656              Stuart Fitzsimmons   M  19.0   Great Britain  GBR
# 69996  35656              Stuart Fitzsimmons   M  19.0   Great Britain  GBR
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0       Australia  AUS
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0       Australia  AUS
# 69999  35658                    Marek Fiurek   M  23.0  Czech Republic  CZE
#
# ...

# %%
olympics_data.to_csv('olympics_history_cleaned_data.csv', index=False)

# %%
dd = pd.read_csv('noc_region.csv')

# %%
dd = dd.drop(['notes'],axis = 1)

# %%
dd
# Out:
#     noc_region          reg
# 0          AFG  Afghanistan
# 1          AHO      Curacao
# 2          ALB      Albania
# 3          ALG      Algeria
# 4          AND      Andorra
# ..         ...          ...
# 225        YEM        Yemen
# 226        YMD        Yemen
# 227        YUG       Serbia
# 228        ZAM       Zambia
# 229        ZIM     Zimbabwe
#
# [230 rows x 2 columns]

# %%
dd = dd.rename(columns={"noc_region": "NOC", "reg": "region"})

# %%
dd
# Out:
#      NOC       region
# 0    AFG  Afghanistan
# 1    AHO      Curacao
# 2    ALB      Albania
# 3    ALG      Algeria
# 4    AND      Andorra
# ..   ...          ...
# 225  YEM        Yemen
# 226  YMD        Yemen
# 227  YUG       Serbia
# 228  ZAM       Zambia
# 229  ZIM     Zimbabwe
#
# [230 rows x 2 columns]

# %%
dd.to_csv('olympics_history_noc_regions_cleaned.csv',index = False)
